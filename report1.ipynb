# %%
import pandas as pd


df = pd.read_csv("UL_PRB_data_set.csv")

# %%
df.head()
# Out:
#   Short name                 Date  N.PRB.UL.DrbUsed.Avg[%]  N.ThpVol.UL  \
# 0    cell000  2025-01-20 00:00:00                 0.178846     6173.480
# 1    cell000  2025-01-20 00:15:00                 0.096154     2877.464
# 2    cell000  2025-01-20 00:30:00                 0.075000     3541.224
# 3    cell000  2025-01-20 00:45:00                 0.148077     9373.480
# 4    cell000  2025-01-20 01:00:00                 0.563462    39179.448
#
#    N.User.RRCConn.Active.UL.Avg
# 0                         0.052
# 1                         0.018
# 2                         0.021
# 3                         0.033
# 4                         0.124
